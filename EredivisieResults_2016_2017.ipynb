# %% [markdown]
# #Data Exploration and Preparation for Football Results Eredivisie 2016/2017
#
# Sections
#
# [1. Get Fixtures for Eredivisie 2016/2017](#get-fixtures)
#
# [2. Get Stadiums](#get-stadiums)
#
# [3. Plot Fixtures on a Map](#map-fixtures)
#
# [4. Get Week-by-Week League Standings](#league-standings)
#
#
# Note: used http://sebastianraschka.com/Articles/2014_ipython_internal_links.html for creation of table of contents

# %% [markdown]
# <a id="get-fixtures"/>

# %% [markdown]
# #Get Fixtures for Eredivisie 2016/2017
#
# Fixture data is fetched from a Football Data API - home at [http://api.football-data.org/index]
#
# ##Get a list of all competitions.

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
# included the above in the first cell because of http://stackoverflow.com/questions/19410042/how-to-make-ipython-notebook-matplotlib-plot-inline

import pandas as pd
import json
import requests
#the API Token to use for API Football-Data is stored in file football-api-key.txt
# if that file does not exist, the notebook will still run, but with some limitations 
# regarding the number of calls that can be made to the API
footballAPIKey='';
try:
    with open("football-api-key.txt") as file:  
          footballAPIKey = file.read() 
except FileNotFoundError:
    print("File football-api-key.txt was not found; proceeding without API Key")
          
APIKeyHttpHeaderName = "X-Auth-Token" 


url2016competitions =  "http://api.football-data.org/v1/competitions/?season=2016"
headers={}
if (footballAPIKey) :
    headers = {APIKeyHttpHeaderName: footballAPIToken}

#docs on requests library: http://docs.python-requests.org/en/master/
d = json.loads(requests.get(url2016competitions,headers=headers).text)
df = pd.DataFrame(d)
df
# Out:
#                                                _links  \
# 0   {'self': {'href': 'http://api.football-data.or...
# 1   {'self': {'href': 'http://api.football-data.or...
# 2   {'self': {'href': 'http://api.football-data.or...
# 3   {'self': {'href': 'http://api.football-data.or...
# 4   {'self': {'href': 'http://api.football-data.or...
# 5   {'self': {'href': 'http://api.football-data.or...
# 6   {'self': {'href': 'http://api.football-data.or...
# 7   {'self': {'href': 'http://api.football-data.or...
# 8   {'self': {'href': 'http://api.football-data.or...
# 9   {'self': {'href': 'http://api.football-data.or...
# 10  {'self': {'href': 'http://api.football-data.or...
# 11  {'self': {'href': 'http://api.football-data.or...
# 12  {'self': {'href': 'http://api.football-data.or...
# 13  {'self': {'href': 'http://api.football-data.or...
# 14  {'self': {'href': 'http://api.football-data.or...
# 15  {'self': {'href': 'http://api.football-data.or...
# 16  {'self': {'href': 'http://api.football-data.or...
# 17  {'self': {'href': 'http://api.football-data.or...
# 18  {'self': {'href': 'http://api.football-data.or...
#
#                                caption  currentMatchday   id  \
# 0   European Championships France 2016                7  424
# 1               Premier League 2016/17               38  426
# 2                 Championship 2016/17               46  427
# 3                   League One 2016/17               46  428
# 4                       FA-Cup 2016/17                8  429
# 5                1. Bundesliga 2016/17               34  430
# 6                2. Bundesliga 2016/17               34  431
# 7                    DFB-Pokal 2016/17                6  432
# 8                   Eredivisie 2016/17               34  433
# 9                      Ligue 1 2016/17               38  434
# 10                     Ligue 2 2016/17               38  435
# 11            Primera Division 2016/17               38  436
# 12               Liga Adelante 2016/17               42  437
# 13                     Serie A 2016/17               38  438
# 14               Primeira Liga 2016/17               34  439
# 15            Champions League 2016/17               10  440
# 16                             Serie B               42  441
# 17             English National League               46  442
# 18                          League Two               46  443
#
#              lastUpdated league  numberOfGames  numberOfMatchdays  \
# 0   2017-04-16T09:10:22Z     EC             51                 46
# 1   2017-05-21T16:00:18Z     PL            380                 38
# 2   2017-05-07T16:20:16Z    ELC            552                 46
# 3   2017-04-30T14:30:21Z    EL1            552                 46
# 4   2017-05-28T06:07:24Z    FAC            156                 38
# 5   2017-05-20T20:20:11Z    BL1            306                 34
# 6   2017-05-21T19:40:13Z    BL2            306                 34
# 7   2017-05-28T06:05:47Z    DFB             63                126
# 8   2017-05-14T14:30:20Z    DED            306                 34
# 9   2017-05-21T05:50:20Z    FL1            380                 38
# 10  2017-05-19T21:50:21Z    FL2            380                 38
# 11  2017-05-21T20:00:24Z     PD            380                 38
# 12  2017-06-14T09:40:27Z     SD            462                 42
# 13  2017-05-28T20:50:29Z     SA            380                 38
# 14  2017-05-26T08:58:18Z    PPL            306                 34
# 15  2017-06-03T20:50:30Z     CL            125                 62
# 16  2017-05-18T20:30:48Z     SB            462                 42
# 17  2017-04-29T13:30:37Z    ENL            552                 46
# 18  2017-05-06T20:00:51Z    EL2            552                 46
#
#     numberOfTeams  year
# 0              24  2016
# 1              20  2016
# 2              24  2016
# 3              24  2016
# 4              20  2016
# 5              18  2016
# 6              18  2016
# 7              64  2016
# 8              18  2016
# 9              20  2016
# 10             20  2016
# 11             20  2016
# 12             22  2016
# 13             20  2016
# 14             18  2016
# 15             32  2016
# 16             22  2016
# 17             24  2016
# 18             24  2016

# %%
league = df[df['league']=="DED"]
league
leagueId = league.iloc[0]['id']
leagueId
# Out:
# 433

# %% [markdown]
# ##Get Fixtures for the competition
#
# Here we have the identifier for the Eredivisie for the competition of 2016/2017.
# Now let's get the fixtures.

# %%
url2016fixtures =  "http://api.football-data.org/v1/competitions/{0}/fixtures".format(leagueId)
url2016fixtures


d = json.loads(requests.get(url2016fixtures, headers=headers).text)

list(d.keys())
# Out:
# ['_links', 'count', 'fixtures']

# %%
fixtures = pd.DataFrame(d["fixtures"])
fixtures.head(5)
# Out:
#                                               _links  \
# 0  {'self': {'href': 'http://api.football-data.or...
# 1  {'self': {'href': 'http://api.football-data.or...
# 2  {'self': {'href': 'http://api.football-data.or...
# 3  {'self': {'href': 'http://api.football-data.or...
# 4  {'self': {'href': 'http://api.football-data.or...
#
#                awayTeamName                  date        homeTeamName  \
# 0                PEC Zwolle  2016-08-05T18:00:00Z        NEC Nijmegen
# 1  Go Ahead Eagles Deventer  2016-08-06T16:30:00Z        ADO Den Haag
# 2                 Excelsior  2016-08-06T17:45:00Z  FC Twente Enschede
# 3             PSV Eindhoven  2016-08-06T17:45:00Z          FC Utrecht
# 4            Vitesse Arnhem  2016-08-06T18:45:00Z   Willem II Tilburg
#
#    matchday                                             odds  \
# 0         1   {'homeWin': 2.15, 'draw': 3.4, 'awayWin': 2.8}
# 1         1  {'homeWin': 1.53, 'draw': 3.75, 'awayWin': 5.0}
# 2         1   {'homeWin': 1.66, 'draw': 3.6, 'awayWin': 4.2}
# 3         1   {'homeWin': 3.5, 'draw': 3.5, 'awayWin': 1.83}
# 4         1                                             None
#
#                                               result    status
# 0  {'goalsHomeTeam': 1, 'goalsAwayTeam': 1, 'half...  FINISHED
# 1  {'goalsHomeTeam': 3, 'goalsAwayTeam': 0, 'half...  FINISHED
# 2  {'goalsHomeTeam': 1, 'goalsAwayTeam': 2, 'half...  FINISHED
# 3  {'goalsHomeTeam': 1, 'goalsAwayTeam': 2, 'half...  FINISHED
# 4  {'goalsHomeTeam': 1, 'goalsAwayTeam': 4, 'half...  FINISHED

# %% [markdown]
# Create column real_timestamp with a value recognized as a real timestamp type;
#
# also derive weekday (monday (0) ..sunday (6))
# and time of fixture
#
# note: the time is defined in UTC - which is two hours earlier than local time (at least some of the year...)

# %%
fixtures['real_timestamp'] = pd.to_datetime(fixtures['date'])
fixtures['weekday'] = fixtures['real_timestamp'].dt.dayofweek
fixtures['startingHour'] = fixtures['real_timestamp'].dt.hour

fixtures.head(25)
# Out:
#                                                _links  \
# 0   {'self': {'href': 'http://api.football-data.or...
# 1   {'self': {'href': 'http://api.football-data.or...
# 2   {'self': {'href': 'http://api.football-data.or...
# 3   {'self': {'href': 'http://api.football-data.or...
# 4   {'self': {'href': 'http://api.football-data.or...
# 5   {'self': {'href': 'http://api.football-data.or...
# 6   {'self': {'href': 'http://api.football-data.or...
# 7   {'self': {'href': 'http://api.football-data.or...
# 8   {'self': {'href': 'http://api.football-data.or...
# 9   {'self': {'href': 'http://api.football-data.or...
# 10  {'self': {'href': 'http://api.football-data.or...
# 11  {'self': {'href': 'http://api.football-data.or...
# 12  {'self': {'href': 'http://api.football-data.or...
# 13  {'self': {'href': 'http://api.football-data.or...
# 14  {'self': {'href': 'http://api.football-data.or...
# 15  {'self': {'href': 'http://api.football-data.or...
# 16  {'self': {'href': 'http://api.football-data.or...
# 17  {'self': {'href': 'http://api.football-data.or...
# 18  {'self': {'href': 'http://api.football-data.or...
# 19  {'self': {'href': 'http://api.football-data.or...
# 20  {'self': {'href': 'http://api.football-data.or...
# 21  {'self': {'href': 'http://api.football-data.or...
# 22  {'self': {'href': 'http://api.football-data.or...
# 23  {'self': {'href': 'http://api.football-data.or...
# 24  {'self': {'href': 'http://api.football-data.or...
#
#                 awayTeamName                  date              homeTeamName  \
# 0                 PEC Zwolle  2016-08-05T18:00:00Z              NEC Nijmegen
# 1   Go Ahead Eagles Deventer  2016-08-06T16:30:00Z              ADO Den Haag
# 2                  Excelsior  2016-08-06T17:45:00Z        FC Twente Enschede
# 3              PSV Eindhoven  2016-08-06T17:45:00Z                FC Utrecht
# 4             Vitesse Arnhem  2016-08-06T18:45:00Z         Willem II Tilburg
# 5        Feyenoord Rotterdam  2016-08-07T10:30:00Z              FC Groningen
# 6              SC Heerenveen  2016-08-07T12:30:00Z                AZ Alkmaar
# 7             Ajax Amsterdam  2016-08-07T12:30:00Z          Sparta Rotterdam
# 8            Heracles Almelo  2016-08-07T14:45:00Z          Roda JC Kerkrade
# 9                 FC Utrecht  2016-08-12T18:00:00Z             SC Heerenveen
# 10              FC Groningen  2016-08-13T16:30:00Z                 Excelsior
# 11          Roda JC Kerkrade  2016-08-13T17:45:00Z            Ajax Amsterdam
# 12              ADO Den Haag  2016-08-13T17:45:00Z            Vitesse Arnhem
# 13          Sparta Rotterdam  2016-08-13T18:45:00Z                PEC Zwolle
# 14         Willem II Tilburg  2016-08-14T10:30:00Z           Heracles Almelo
# 15              NEC Nijmegen  2016-08-14T12:30:00Z  Go Ahead Eagles Deventer
# 16        FC Twente Enschede  2016-08-14T12:30:00Z       Feyenoord Rotterdam
# 17                AZ Alkmaar  2016-08-14T14:45:00Z             PSV Eindhoven
# 18              ADO Den Haag  2016-08-19T18:00:00Z                 Excelsior
# 19            Vitesse Arnhem  2016-08-20T16:30:00Z          Roda JC Kerkrade
# 20             PSV Eindhoven  2016-08-20T17:45:00Z                PEC Zwolle
# 21         Willem II Tilburg  2016-08-20T17:45:00Z            Ajax Amsterdam
# 22             SC Heerenveen  2016-08-20T18:45:00Z              NEC Nijmegen
# 23        FC Twente Enschede  2016-08-21T10:30:00Z              FC Groningen
# 24                AZ Alkmaar  2016-08-21T12:30:00Z                FC Utrecht
#
#     matchday                                             odds  \
# 0          1   {'homeWin': 2.15, 'draw': 3.4, 'awayWin': 2.8}
# 1          1  {'homeWin': 1.53, 'draw': 3.75, 'awayWin': 5.0}
# 2          1   {'homeWin': 1.66, 'draw': 3.6, 'awayWin': 4.2}
# 3          1   {'homeWin': 3.5, 'draw': 3.5, 'awayWin': 1.83}
# 4          1                                             None
# 5          1    {'homeWin': 3.1, 'draw': 3.3, 'awayWin': 2.0}
# 6          1   {'homeWin': 1.57, 'draw': 3.9, 'awayWin': 4.5}
# 7          1   {'homeWin': 7.0, 'draw': 4.4, 'awayWin': 1.35}
# 8          1    {'homeWin': 2.3, 'draw': 3.3, 'awayWin': 3.1}
# 9          2                                             None
# 10         2                                             None
# 11         2                                             None
# 12         2                                             None
# 13         2                                             None
# 14         2   {'homeWin': 2.05, 'draw': 3.3, 'awayWin': 3.7}
# 15         2    {'homeWin': 2.4, 'draw': 3.5, 'awayWin': 2.8}
# 16         2  {'homeWin': 1.25, 'draw': 6.5, 'awayWin': 13.0}
# 17         2   {'homeWin': 1.44, 'draw': 5.0, 'awayWin': 7.5}
# 18         3  {'homeWin': 3.2, 'draw': 3.25, 'awayWin': 2.25}
# 19         3    {'homeWin': 3.2, 'draw': 3.3, 'awayWin': 2.2}
# 20         3  {'homeWin': 7.5, 'draw': 4.33, 'awayWin': 1.44}
# 21         3  {'homeWin': 1.25, 'draw': 5.5, 'awayWin': 13.0}
# 22         3   {'homeWin': 2.6, 'draw': 3.3, 'awayWin': 2.62}
# 23         3   {'homeWin': 2.15, 'draw': 3.4, 'awayWin': 3.2}
# 24         3   {'homeWin': 2.37, 'draw': 3.3, 'awayWin': 2.9}
#
#                                                result    status  \
# 0   {'goalsHomeTeam': 1, 'goalsAwayTeam': 1, 'half...  FINISHED
# 1   {'goalsHomeTeam': 3, 'goalsAwayTeam': 0, 'half...  FINISHED
# 2   {'goalsHomeTeam': 1, 'goalsAwayTeam': 2, 'half...  FINISHED
# 3   {'goalsHomeTeam': 1, 'goalsAwayTeam': 2, 'half...  FINISHED
# 4   {'goalsHomeTeam': 1, 'goalsAwayTeam': 4, 'half...  FINISHED
# 5   {'goalsHomeTeam': 0, 'goalsAwayTeam': 5, 'half...  FINISHED
# 6   {'goalsHomeTeam': 2, 'goalsAwayTeam': 2, 'half...  FINISHED
# 7   {'goalsHomeTeam': 1, 'goalsAwayTeam': 3, 'half...  FINISHED
# 8   {'goalsHomeTeam': 1, 'goalsAwayTeam': 1, 'half...  FINISHED
# 9   {'goalsHomeTeam': 2, 'goalsAwayTeam': 2, 'half...  FINISHED
# 10  {'goalsHomeTeam': 2, 'goalsAwayTeam': 0, 'half...  FINISHED
# 11  {'goalsHomeTeam': 2, 'goalsAwayTeam': 2, 'half...  FINISHED
# 12  {'goalsHomeTeam': 1, 'goalsAwayTeam': 2, 'half...  FINISHED
# 13  {'goalsHomeTeam': 0, 'goalsAwayTeam': 3, 'half...  FINISHED
# 14  {'goalsHomeTeam': 3, 'goalsAwayTeam': 1, 'half...  FINISHED
# 15           {'goalsHomeTeam': 2, 'goalsAwayTeam': 2}  FINISHED
# 16           {'goalsHomeTeam': 2, 'goalsAwayTeam': 0}  FINISHED
# 17           {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}  FINISHED
# 18           {'goalsHomeTeam': 1, 'goalsAwayTeam': 2}  FINISHED
# 19           {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}  FINISHED
# 20           {'goalsHomeTeam': 0, 'goalsAwayTeam': 4}  FINISHED
# 21           {'goalsHomeTeam': 1, 'goalsAwayTeam': 2}  FINISHED
# 22           {'goalsHomeTeam': 2, 'goalsAwayTeam': 1}  FINISHED
# 23           {'goalsHomeTeam': 3, 'goalsAwayTeam': 4}  FINISHED
# 24           {'goalsHomeTeam': 1, 'goalsAwayTeam': 2}  FINISHED
#
#         real_timestamp  weekday  startingHour
# 0  2016-08-05 18:00:00        4            18
# 1  2016-08-06 16:30:00        5            16
# 2  2016-08-06 17:45:00        5            17
# 3  2016-08-06 17:45:00        5            17
# 4  2016-08-06 18:45:00        5            18
# 5  2016-08-07 10:30:00        6            10
# 6  2016-08-07 12:30:00        6            12
# 7  2016-08-07 12:30:00        6            12
# 8  2016-08-07 14:45:00        6            14
# 9  2016-08-12 18:00:00        4            18
# 10 2016-08-13 16:30:00        5            16
# 11 2016-08-13 17:45:00        5            17
# 12 2016-08-13 17:45:00        5            17
# 13 2016-08-13 18:45:00        5            18
# 14 2016-08-14 10:30:00        6            10
# 15 2016-08-14 12:30:00        6            12
# 16 2016-08-14 12:30:00        6            12
# 17 2016-08-14 14:45:00        6            14
# 18 2016-08-19 18:00:00        4            18
# 19 2016-08-20 16:30:00        5            16
# 20 2016-08-20 17:45:00        5            17
# 21 2016-08-20 17:45:00        5            17
# 22 2016-08-20 18:45:00        5            18
# 23 2016-08-21 10:30:00        6            10
# 24 2016-08-21 12:30:00        6            12

# %% [markdown]
# Time to extract the nested data for the result. At least create columns for:
# * homeGoals
# * awayGoals
# * outcome (3,1,0 for win, draw, loss)

# %%
outcome = pd.read_json(fixtures['result'].to_json())
                           
outcome
# Out:
#                                                     0    \
# goalsAwayTeam                                         1
# goalsHomeTeam                                         1
# halfTime       {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}
#
#                                                     1    \
# goalsAwayTeam                                         0
# goalsHomeTeam                                         3
# halfTime       {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}
#
#                                                     10   \
# goalsAwayTeam                                         0
# goalsHomeTeam                                         2
# halfTime       {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}
#
#                                                     100  \
# goalsAwayTeam                                         0
# goalsHomeTeam                                         1
# halfTime       {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}
#
#                                                     101  \
# goalsAwayTeam                                         1
# goalsHomeTeam                                         1
# halfTime       {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}
#
#                                                     102  \
# goalsAwayTeam                                         1
# goalsHomeTeam                                         1
# halfTime       {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}
#
#                                                     103  \
# goalsAwayTeam                                         0
# goalsHomeTeam                                         0
# halfTime       {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}
#
#                                                     104  \
# goalsAwayTeam                                         1
# goalsHomeTeam                                         2
# halfTime       {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}
#
#                                                     105  \
# goalsAwayTeam                                         2
# goalsHomeTeam                                         2
# halfTime       {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}
#
#                                                     106  \
# goalsAwayTeam                                         2
# goalsHomeTeam                                         1
# halfTime       {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}
#
#                                  ...                     \
# goalsAwayTeam                    ...
# goalsHomeTeam                    ...
# halfTime                         ...
#
#                                                     90   \
# goalsAwayTeam                                         0
# goalsHomeTeam                                         0
# halfTime       {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}
#
#                                                     91   \
# goalsAwayTeam                                         1
# goalsHomeTeam                                         2
# halfTime       {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}
#
#                                                     92   \
# goalsAwayTeam                                         2
# goalsHomeTeam                                         0
# halfTime       {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}
#
#                                                     93   \
# goalsAwayTeam                                         2
# goalsHomeTeam                                         2
# halfTime       {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}
#
#                                                     94   \
# goalsAwayTeam                                         0
# goalsHomeTeam                                         1
# halfTime       {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}
#
#                                                     95   \
# goalsAwayTeam                                         1
# goalsHomeTeam                                         3
# halfTime       {'goalsHomeTeam': 1, 'goalsAwayTeam': 1}
#
#                                                     96   \
# goalsAwayTeam                                         1
# goalsHomeTeam                                         1
# halfTime       {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}
#
#                                                     97   \
# goalsAwayTeam                                         2
# goalsHomeTeam                                         2
# halfTime       {'goalsHomeTeam': 2, 'goalsAwayTeam': 1}
#
#                                                     98   \
# goalsAwayTeam                                         1
# goalsHomeTeam                                         0
# halfTime       {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}
#
#                                                     99
# goalsAwayTeam                                         1
# goalsHomeTeam                                         3
# halfTime       {'goalsHomeTeam': 2, 'goalsAwayTeam': 1}
#
# [3 rows x 306 columns]

# %%
#outcome.pivot(index='index_col')
#to pivot around outcome


outcome.T.head(5)
# Out:
#     goalsAwayTeam goalsHomeTeam                                  halfTime
# 0               1             1  {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}
# 1               0             3  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}
# 10              0             2  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}
# 100             0             1  {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}
# 101             1             1  {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}

# %% [markdown]
# In the next section, add the columns goalsAwayTeam and goalsHomeTeam to dataframe fixtures, based on the transposed outcome dataframe.

# %%
fixtures= pd.concat([fixtures, outcome.T], axis=1, join_axes=[fixtures.index])
fixtures.head(5)
# Out:
#                                               _links  \
# 0  {'self': {'href': 'http://api.football-data.or...
# 1  {'self': {'href': 'http://api.football-data.or...
# 2  {'self': {'href': 'http://api.football-data.or...
# 3  {'self': {'href': 'http://api.football-data.or...
# 4  {'self': {'href': 'http://api.football-data.or...
#
#                awayTeamName                  date        homeTeamName  \
# 0                PEC Zwolle  2016-08-05T18:00:00Z        NEC Nijmegen
# 1  Go Ahead Eagles Deventer  2016-08-06T16:30:00Z        ADO Den Haag
# 2                 Excelsior  2016-08-06T17:45:00Z  FC Twente Enschede
# 3             PSV Eindhoven  2016-08-06T17:45:00Z          FC Utrecht
# 4            Vitesse Arnhem  2016-08-06T18:45:00Z   Willem II Tilburg
#
#    matchday                                             odds  \
# 0         1   {'homeWin': 2.15, 'draw': 3.4, 'awayWin': 2.8}
# 1         1  {'homeWin': 1.53, 'draw': 3.75, 'awayWin': 5.0}
# 2         1   {'homeWin': 1.66, 'draw': 3.6, 'awayWin': 4.2}
# 3         1   {'homeWin': 3.5, 'draw': 3.5, 'awayWin': 1.83}
# 4         1                                             None
#
#                                               result    status  \
# 0  {'goalsHomeTeam': 1, 'goalsAwayTeam': 1, 'half...  FINISHED
# 1  {'goalsHomeTeam': 3, 'goalsAwayTeam': 0, 'half...  FINISHED
# 2  {'goalsHomeTeam': 1, 'goalsAwayTeam': 2, 'half...  FINISHED
# 3  {'goalsHomeTeam': 1, 'goalsAwayTeam': 2, 'half...  FINISHED
# 4  {'goalsHomeTeam': 1, 'goalsAwayTeam': 4, 'half...  FINISHED
#
#        real_timestamp  weekday  startingHour goalsAwayTeam goalsHomeTeam  \
# 0 2016-08-05 18:00:00        4            18             1             1
# 1 2016-08-06 16:30:00        5            16             0             3
# 2 2016-08-06 17:45:00        5            17             2             1
# 3 2016-08-06 17:45:00        5            17             2             1
# 4 2016-08-06 18:45:00        5            18             4             1
#
#                                    halfTime
# 0  {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}
# 1  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}
# 2  {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}
# 3  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}
# 4  {'goalsHomeTeam': 0, 'goalsAwayTeam': 4}

# %%
fixtures.columns
# Out:
# Index(['_links', 'awayTeamName', 'date', 'homeTeamName', 'matchday', 'odds',
#        'result', 'status', 'real_timestamp', 'weekday', 'startingHour',
#        'goalsAwayTeam', 'goalsHomeTeam', 'halfTime'],
#       dtype='object')

# %% [markdown]
# Add derived column outcome - 3,1,0 for win,draw,loss for home team
# First create a function to derive the match result based on the respective number of goals scored by home and away team
# Then derive the new column by applying this function to all rows.

# %%
def match_result(x):
      result = 1
      if x['goalsAwayTeam']> x['goalsHomeTeam']:
        result=2
      elif x['goalsAwayTeam']== x['goalsHomeTeam']:
        result=3
      return result

# %%
fixtures['outcome'] = fixtures.apply(match_result, axis=1)
fixtures.head(5)
# Out:
#                                               _links  \
# 0  {'self': {'href': 'http://api.football-data.or...
# 1  {'self': {'href': 'http://api.football-data.or...
# 2  {'self': {'href': 'http://api.football-data.or...
# 3  {'self': {'href': 'http://api.football-data.or...
# 4  {'self': {'href': 'http://api.football-data.or...
#
#                awayTeamName                  date        homeTeamName  \
# 0                PEC Zwolle  2016-08-05T18:00:00Z        NEC Nijmegen
# 1  Go Ahead Eagles Deventer  2016-08-06T16:30:00Z        ADO Den Haag
# 2                 Excelsior  2016-08-06T17:45:00Z  FC Twente Enschede
# 3             PSV Eindhoven  2016-08-06T17:45:00Z          FC Utrecht
# 4            Vitesse Arnhem  2016-08-06T18:45:00Z   Willem II Tilburg
#
#    matchday                                             odds  \
# 0         1   {'homeWin': 2.15, 'draw': 3.4, 'awayWin': 2.8}
# 1         1  {'homeWin': 1.53, 'draw': 3.75, 'awayWin': 5.0}
# 2         1   {'homeWin': 1.66, 'draw': 3.6, 'awayWin': 4.2}
# 3         1   {'homeWin': 3.5, 'draw': 3.5, 'awayWin': 1.83}
# 4         1                                             None
#
#                                               result    status  \
# 0  {'goalsHomeTeam': 1, 'goalsAwayTeam': 1, 'half...  FINISHED
# 1  {'goalsHomeTeam': 3, 'goalsAwayTeam': 0, 'half...  FINISHED
# 2  {'goalsHomeTeam': 1, 'goalsAwayTeam': 2, 'half...  FINISHED
# 3  {'goalsHomeTeam': 1, 'goalsAwayTeam': 2, 'half...  FINISHED
# 4  {'goalsHomeTeam': 1, 'goalsAwayTeam': 4, 'half...  FINISHED
#
#        real_timestamp  weekday  startingHour goalsAwayTeam goalsHomeTeam  \
# 0 2016-08-05 18:00:00        4            18             1             1
# 1 2016-08-06 16:30:00        5            16             0             3
# 2 2016-08-06 17:45:00        5            17             2             1
# 3 2016-08-06 17:45:00        5            17             2             1
# 4 2016-08-06 18:45:00        5            18             4             1
#
#                                    halfTime  outcome
# 0  {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}        3
# 1  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}        1
# 2  {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}        2
# 3  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}        2
# 4  {'goalsHomeTeam': 0, 'goalsAwayTeam': 4}        2

# %% [markdown]
# Some of the things we should do next:
# - do some aggregations on what we currently have (such as number of wins, draws and losses; average number of goals (per match? per playday/matchround)
# - add set of stadiums (address, geolocation, capacity)
# - plot number of matches per city on a map (see https://www.dataquest.io/blog/python-json-tutorial/ for an example)
# - add leaguestandings (from http://api.football-data.org/v1/competitions/433/leagueTable?matchday=12)
# - add weather details
# - add historis head2head details (from http://api.football-data.org/v1/fixtures/153552?head2head=5 , using the self.href URL in _links column)
#
# First, write current set of fixture data to CSV file.

# %%
fixtures.to_csv('fixtures-20162017.csv')

# %% [markdown]
# Let's create a list of Stadiums. A Data Frame with the following columns:
# * Team
# * Name
# * Capacity
# * City
# * Longitude
# * Lattitude

# %%
stadiums = pd.DataFrame(
    [ {'Team': 'PSV Eindhoven', 'Capacity':36500, 'City':'Eindhoven', 'Lattitude':51.441462, 'Longitude':5.466528, 'Name':'Philipsstadion','PitchType':'Natural'}
    , {'Team': 'Vitesse Arnhem', 'Capacity':25000, 'City':'Arnhem', 'Lattitude':51.964289, 'Longitude':5.8894493,'Name':'GelreDome','PitchType':'Natural'}
    , {'Team': 'Excelsior', 'Capacity':4400, 'City':'Rotterdam', 'Lattitude':51.9175164, 'Longitude':4.5177137,'Name':'Stadion Woudestein','PitchType':'Natural'}
    , {'Team': 'FC Twente Enschede', 'Capacity':30205, 'City':'Enschede', 'Lattitude':52.2365348, 'Longitude':6.8356701,'Name':'De Grolsch Veste','PitchType':'Natural'}       
    , {'Team': 'Feyenoord Rotterdam', 'Capacity':51117, 'City':'Rotterdam', 'Lattitude':51.8939035, 'Longitude':4.5209467,'Name':'Stadion Feijenoord','PitchType':'Natural'}       
    , {'Team': 'Sparta Rotterdam', 'Capacity':11000, 'City':'Rotterdam', 'Lattitude':51.9199557, 'Longitude':4.43085,'Name':'Sparta-Stadion Het Kasteel','PitchType':'Synthetic'}       
    , {'Team': 'ADO Den Haag', 'Capacity':15000, 'City':'Den Haag', 'Lattitude':52.0629342, 'Longitude':4.3805384,'Name':'Kyocera-stadion','PitchType':'Synthetic'}       
    , {'Team': 'FC Groningen', 'Capacity':22579, 'City':'Groningen', 'Lattitude':53.2067866, 'Longitude':6.5898065,'Name':'Euroborg','PitchType':'Natural'}       
    , {'Team': 'SC Heerenveen', 'Capacity':261000, 'City':'Heerenveen', 'Lattitude':52.9587432, 'Longitude':5.9338243,'Name':'Abe Lenstra Stadion','PitchType':'Natural'}       
    ])
stadiums
# Out:
#    Capacity        City  Lattitude  Longitude                        Name  \
# 0     36500   Eindhoven  51.441462   5.466528              Philipsstadion
# 1     25000      Arnhem  51.964289   5.889449                   GelreDome
# 2      4400   Rotterdam  51.917516   4.517714          Stadion Woudestein
# 3     30205    Enschede  52.236535   6.835670            De Grolsch Veste
# 4     51117   Rotterdam  51.893904   4.520947          Stadion Feijenoord
# 5     11000   Rotterdam  51.919956   4.430850  Sparta-Stadion Het Kasteel
# 6     15000    Den Haag  52.062934   4.380538             Kyocera-stadion
# 7     22579   Groningen  53.206787   6.589806                    Euroborg
# 8    261000  Heerenveen  52.958743   5.933824         Abe Lenstra Stadion
#
#    PitchType                 Team
# 0    Natural        PSV Eindhoven
# 1    Natural       Vitesse Arnhem
# 2    Natural            Excelsior
# 3    Natural   FC Twente Enschede
# 4    Natural  Feyenoord Rotterdam
# 5  Synthetic     Sparta Rotterdam
# 6  Synthetic         ADO Den Haag
# 7    Natural         FC Groningen
# 8    Natural        SC Heerenveen

# %% [markdown]
# Add stadium attributes to fixtures table - joining on homeTeamName
# (use https://chrisalbon.com/python/pd_join_merge_dataframe.html for merge details)

# %%
fixtures = pd.merge(fixtures, stadiums, left_on='homeTeamName', right_on='Team', how='left')

# %% [markdown]
# Let's show some data on the map- for example a count of matches

# %%
import folium
from folium import plugins

# %%
#number of fixtures per city
city_counts = fixtures.groupby(['City']).size()
city_counts
# Out:
# City
# Arnhem        17
# Den Haag      17
# Eindhoven     17
# Enschede      17
# Groningen     17
# Heerenveen    17
# Rotterdam     51
# dtype: int64

# %%
#filter rows with geo location
fixtures[fixtures.Longitude.notnull() & fixtures.Lattitude.notnull()]
# Out:
#                                                 _links  \
# 1    {'self': {'href': 'http://api.football-data.or...
# 2    {'self': {'href': 'http://api.football-data.or...
# 5    {'self': {'href': 'http://api.football-data.or...
# 7    {'self': {'href': 'http://api.football-data.or...
# 9    {'self': {'href': 'http://api.football-data.or...
# 10   {'self': {'href': 'http://api.football-data.or...
# 12   {'self': {'href': 'http://api.football-data.or...
# 16   {'self': {'href': 'http://api.football-data.or...
# 17   {'self': {'href': 'http://api.football-data.or...
# 18   {'self': {'href': 'http://api.football-data.or...
# 23   {'self': {'href': 'http://api.football-data.or...
# 25   {'self': {'href': 'http://api.football-data.or...
# 27   {'self': {'href': 'http://api.football-data.or...
# 29   {'self': {'href': 'http://api.football-data.or...
# 30   {'self': {'href': 'http://api.football-data.or...
# 31   {'self': {'href': 'http://api.football-data.or...
# 32   {'self': {'href': 'http://api.football-data.or...
# 34   {'self': {'href': 'http://api.football-data.or...
# 39   {'self': {'href': 'http://api.football-data.or...
# 40   {'self': {'href': 'http://api.football-data.or...
# 41   {'self': {'href': 'http://api.football-data.or...
# 43   {'self': {'href': 'http://api.football-data.or...
# 46   {'self': {'href': 'http://api.football-data.or...
# 47   {'self': {'href': 'http://api.football-data.or...
# 50   {'self': {'href': 'http://api.football-data.or...
# 52   {'self': {'href': 'http://api.football-data.or...
# 54   {'self': {'href': 'http://api.football-data.or...
# 55   {'self': {'href': 'http://api.football-data.or...
# 57   {'self': {'href': 'http://api.football-data.or...
# 61   {'self': {'href': 'http://api.football-data.or...
# ..                                                 ...
# 248  {'self': {'href': 'http://api.football-data.or...
# 250  {'self': {'href': 'http://api.football-data.or...
# 251  {'self': {'href': 'http://api.football-data.or...
# 252  {'self': {'href': 'http://api.football-data.or...
# 253  {'self': {'href': 'http://api.football-data.or...
# 255  {'self': {'href': 'http://api.football-data.or...
# 258  {'self': {'href': 'http://api.football-data.or...
# 260  {'self': {'href': 'http://api.football-data.or...
# 261  {'self': {'href': 'http://api.football-data.or...
# 262  {'self': {'href': 'http://api.football-data.or...
# 264  {'self': {'href': 'http://api.football-data.or...
# 269  {'self': {'href': 'http://api.football-data.or...
# 272  {'self': {'href': 'http://api.football-data.or...
# 273  {'self': {'href': 'http://api.football-data.or...
# 274  {'self': {'href': 'http://api.football-data.or...
# 276  {'self': {'href': 'http://api.football-data.or...
# 277  {'self': {'href': 'http://api.football-data.or...
# 279  {'self': {'href': 'http://api.football-data.or...
# 285  {'self': {'href': 'http://api.football-data.or...
# 286  {'self': {'href': 'http://api.football-data.or...
# 287  {'self': {'href': 'http://api.football-data.or...
# 288  {'self': {'href': 'http://api.football-data.or...
# 289  {'self': {'href': 'http://api.football-data.or...
# 295  {'self': {'href': 'http://api.football-data.or...
# 299  {'self': {'href': 'http://api.football-data.or...
# 300  {'self': {'href': 'http://api.football-data.or...
# 301  {'self': {'href': 'http://api.football-data.or...
# 302  {'self': {'href': 'http://api.football-data.or...
# 303  {'self': {'href': 'http://api.football-data.or...
# 305  {'self': {'href': 'http://api.football-data.or...
#
#                  awayTeamName                  date         homeTeamName  \
# 1    Go Ahead Eagles Deventer  2016-08-06T16:30:00Z         ADO Den Haag
# 2                   Excelsior  2016-08-06T17:45:00Z   FC Twente Enschede
# 5         Feyenoord Rotterdam  2016-08-07T10:30:00Z         FC Groningen
# 7              Ajax Amsterdam  2016-08-07T12:30:00Z     Sparta Rotterdam
# 9                  FC Utrecht  2016-08-12T18:00:00Z        SC Heerenveen
# 10               FC Groningen  2016-08-13T16:30:00Z            Excelsior
# 12               ADO Den Haag  2016-08-13T17:45:00Z       Vitesse Arnhem
# 16         FC Twente Enschede  2016-08-14T12:30:00Z  Feyenoord Rotterdam
# 17                 AZ Alkmaar  2016-08-14T14:45:00Z        PSV Eindhoven
# 18               ADO Den Haag  2016-08-19T18:00:00Z            Excelsior
# 23         FC Twente Enschede  2016-08-21T10:30:00Z         FC Groningen
# 25   Go Ahead Eagles Deventer  2016-08-21T12:30:00Z     Sparta Rotterdam
# 27                 FC Utrecht  2016-08-26T18:00:00Z       Vitesse Arnhem
# 29                 PEC Zwolle  2016-08-27T17:45:00Z        SC Heerenveen
# 30                  Excelsior  2016-08-27T17:45:00Z  Feyenoord Rotterdam
# 31           Sparta Rotterdam  2016-08-27T18:45:00Z   FC Twente Enschede
# 32               FC Groningen  2016-08-28T10:30:00Z        PSV Eindhoven
# 34            Heracles Almelo  2016-08-28T12:30:00Z         ADO Den Haag
# 39         FC Twente Enschede  2016-09-10T18:45:00Z        SC Heerenveen
# 40            Heracles Almelo  2016-09-10T18:45:00Z            Excelsior
# 41               ADO Den Haag  2016-09-11T10:30:00Z  Feyenoord Rotterdam
# 43           Sparta Rotterdam  2016-09-11T12:30:00Z         FC Groningen
# 46               ADO Den Haag  2016-09-17T16:30:00Z   FC Twente Enschede
# 47   Go Ahead Eagles Deventer  2016-09-17T17:45:00Z       Vitesse Arnhem
# 50               NEC Nijmegen  2016-09-18T10:30:00Z     Sparta Rotterdam
# 52        Feyenoord Rotterdam  2016-09-18T12:30:00Z        PSV Eindhoven
# 54              SC Heerenveen  2016-09-24T16:30:00Z         ADO Den Haag
# 55            Heracles Almelo  2016-09-24T16:30:00Z         FC Groningen
# 57              PSV Eindhoven  2016-09-24T18:45:00Z            Excelsior
# 61             Vitesse Arnhem  2016-09-25T12:30:00Z   FC Twente Enschede
# ..                        ...                   ...                  ...
# 248              NEC Nijmegen  2017-04-02T10:30:00Z       Vitesse Arnhem
# 250          Roda JC Kerkrade  2017-04-02T12:30:00Z         ADO Den Haag
# 251  Go Ahead Eagles Deventer  2017-04-02T14:45:00Z   FC Twente Enschede
# 252                FC Utrecht  2017-04-04T16:30:00Z            Excelsior
# 253          Sparta Rotterdam  2017-04-04T18:45:00Z        SC Heerenveen
# 255              NEC Nijmegen  2017-04-05T17:45:00Z         FC Groningen
# 258  Go Ahead Eagles Deventer  2017-04-05T18:45:00Z  Feyenoord Rotterdam
# 260             PSV Eindhoven  2017-04-06T18:45:00Z   FC Twente Enschede
# 261                 Excelsior  2017-04-07T18:00:00Z     Sparta Rotterdam
# 262             SC Heerenveen  2017-04-08T16:30:00Z       Vitesse Arnhem
# 264              FC Groningen  2017-04-08T17:45:00Z         ADO Den Haag
# 269         Willem II Tilburg  2017-04-09T14:45:00Z        PSV Eindhoven
# 272             PSV Eindhoven  2017-04-15T17:45:00Z         ADO Den Haag
# 273            Vitesse Arnhem  2017-04-15T17:45:00Z            Excelsior
# 274              NEC Nijmegen  2017-04-15T18:45:00Z   FC Twente Enschede
# 276                PEC Zwolle  2017-04-16T12:30:00Z         FC Groningen
# 277                FC Utrecht  2017-04-16T12:30:00Z  Feyenoord Rotterdam
# 279         Willem II Tilburg  2017-04-21T18:00:00Z        SC Heerenveen
# 285              ADO Den Haag  2017-04-23T12:30:00Z     Sparta Rotterdam
# 286       Feyenoord Rotterdam  2017-04-23T12:30:00Z       Vitesse Arnhem
# 287            Ajax Amsterdam  2017-04-23T14:45:00Z        PSV Eindhoven
# 288             PSV Eindhoven  2017-05-07T12:30:00Z         FC Groningen
# 289       Feyenoord Rotterdam  2017-05-07T12:30:00Z            Excelsior
# 295        FC Twente Enschede  2017-05-07T12:30:00Z     Sparta Rotterdam
# 299           Heracles Almelo  2017-05-14T12:30:00Z  Feyenoord Rotterdam
# 300              NEC Nijmegen  2017-05-14T12:30:00Z        SC Heerenveen
# 301                PEC Zwolle  2017-05-14T12:30:00Z        PSV Eindhoven
# 302              FC Groningen  2017-05-14T12:30:00Z   FC Twente Enschede
# 303                 Excelsior  2017-05-14T12:30:00Z         ADO Den Haag
# 305          Roda JC Kerkrade  2017-05-14T12:30:00Z       Vitesse Arnhem
#
#      matchday                                             odds  \
# 1           1  {'homeWin': 1.53, 'draw': 3.75, 'awayWin': 5.0}
# 2           1   {'homeWin': 1.66, 'draw': 3.6, 'awayWin': 4.2}
# 5           1    {'homeWin': 3.1, 'draw': 3.3, 'awayWin': 2.0}
# 7           1   {'homeWin': 7.0, 'draw': 4.4, 'awayWin': 1.35}
# 9           2                                             None
# 10          2                                             None
# 12          2                                             None
# 16          2  {'homeWin': 1.25, 'draw': 6.5, 'awayWin': 13.0}
# 17          2   {'homeWin': 1.44, 'draw': 5.0, 'awayWin': 7.5}
# 18          3  {'homeWin': 3.2, 'draw': 3.25, 'awayWin': 2.25}
# 23          3   {'homeWin': 2.15, 'draw': 3.4, 'awayWin': 3.2}
# 25          3   {'homeWin': 1.72, 'draw': 3.6, 'awayWin': 4.8}
# 27          4    {'homeWin': 1.9, 'draw': 3.5, 'awayWin': 3.9}
# 29          4   {'homeWin': 2.05, 'draw': 3.6, 'awayWin': 3.3}
# 30          4  {'homeWin': 1.14, 'draw': 7.5, 'awayWin': 19.0}
# 31          4  {'homeWin': 1.85, 'draw': 3.75, 'awayWin': 3.8}
# 32          4  {'homeWin': 1.15, 'draw': 7.0, 'awayWin': 17.0}
# 34          4   {'homeWin': 1.85, 'draw': 3.8, 'awayWin': 3.6}
# 39          5   {'homeWin': 1.75, 'draw': 3.6, 'awayWin': 4.4}
# 40          5   {'homeWin': 3.2, 'draw': 3.2, 'awayWin': 2.25}
# 41          5   {'homeWin': 1.33, 'draw': 4.8, 'awayWin': 9.5}
# 43          5    {'homeWin': 2.2, 'draw': 3.4, 'awayWin': 3.2}
# 46          6   {'homeWin': 2.5, 'draw': 3.3, 'awayWin': 2.75}
# 47          6   {'homeWin': 1.33, 'draw': 4.8, 'awayWin': 9.0}
# 50          6   {'homeWin': 1.95, 'draw': 3.4, 'awayWin': 3.9}
# 52          6   {'homeWin': 1.7, 'draw': 3.9, 'awayWin': 4.75}
# 54          7   {'homeWin': 2.37, 'draw': 3.4, 'awayWin': 2.9}
# 55          7    {'homeWin': 1.9, 'draw': 3.7, 'awayWin': 3.8}
# 57          7  {'homeWin': 11.0, 'draw': 5.5, 'awayWin': 1.28}
# 61          7    {'homeWin': 3.3, 'draw': 3.4, 'awayWin': 2.1}
# ..        ...                                              ...
# 248        28   {'homeWin': 1.44, 'draw': 4.2, 'awayWin': 7.5}
# 250        28   {'homeWin': 2.3, 'draw': 3.25, 'awayWin': 3.1}
# 251        28    {'homeWin': 1.5, 'draw': 4.2, 'awayWin': 6.5}
# 252        29   {'homeWin': 3.5, 'draw': 3.4, 'awayWin': 2.05}
# 253        29    {'homeWin': 1.7, 'draw': 3.9, 'awayWin': 4.5}
# 255        29    {'homeWin': 1.8, 'draw': 3.7, 'awayWin': 4.2}
# 258        29  {'homeWin': 1.12, 'draw': 8.0, 'awayWin': 26.0}
# 260        29  {'homeWin': 5.0, 'draw': 4.33, 'awayWin': 1.55}
# 261        30    {'homeWin': 2.0, 'draw': 3.5, 'awayWin': 3.7}
# 262        30   {'homeWin': 2.05, 'draw': 3.4, 'awayWin': 3.5}
# 264        30    {'homeWin': 3.0, 'draw': 3.3, 'awayWin': 2.3}
# 269        30  {'homeWin': 1.15, 'draw': 7.5, 'awayWin': 19.0}
# 272        31  {'homeWin': 12.0, 'draw': 5.5, 'awayWin': 1.25}
# 273        31   {'homeWin': 3.5, 'draw': 3.4, 'awayWin': 2.05}
# 274        31    {'homeWin': 1.5, 'draw': 4.0, 'awayWin': 6.5}
# 276        31   {'homeWin': 2.05, 'draw': 3.5, 'awayWin': 3.3}
# 277        31   {'homeWin': 1.44, 'draw': 4.4, 'awayWin': 7.0}
# 279        32   {'homeWin': 1.66, 'draw': 3.9, 'awayWin': 5.0}
# 285        32    {'homeWin': 2.1, 'draw': 3.4, 'awayWin': 3.3}
# 286        32   {'homeWin': 4.5, 'draw': 4.0, 'awayWin': 1.66}
# 287        32    {'homeWin': 2.2, 'draw': 3.4, 'awayWin': 3.2}
# 288        33   {'homeWin': 6.5, 'draw': 4.8, 'awayWin': 1.44}
# 289        33  {'homeWin': 12.0, 'draw': 6.0, 'awayWin': 1.22}
# 295        33  {'homeWin': 2.37, 'draw': 3.3, 'awayWin': 2.87}
# 299        34   {'homeWin': 1.2, 'draw': 6.5, 'awayWin': 13.0}
# 300        34    {'homeWin': 1.5, 'draw': 4.4, 'awayWin': 6.0}
# 301        34   {'homeWin': 1.2, 'draw': 7.0, 'awayWin': 12.0}
# 302        34   {'homeWin': 2.25, 'draw': 3.7, 'awayWin': 2.8}
# 303        34    {'homeWin': 2.2, 'draw': 3.4, 'awayWin': 3.1}
# 305        34   {'homeWin': 1.8, 'draw': 3.75, 'awayWin': 4.2}
#
#                                                 result    status  \
# 1    {'goalsHomeTeam': 3, 'goalsAwayTeam': 0, 'half...  FINISHED
# 2    {'goalsHomeTeam': 1, 'goalsAwayTeam': 2, 'half...  FINISHED
# 5    {'goalsHomeTeam': 0, 'goalsAwayTeam': 5, 'half...  FINISHED
# 7    {'goalsHomeTeam': 1, 'goalsAwayTeam': 3, 'half...  FINISHED
# 9    {'goalsHomeTeam': 2, 'goalsAwayTeam': 2, 'half...  FINISHED
# 10   {'goalsHomeTeam': 2, 'goalsAwayTeam': 0, 'half...  FINISHED
# 12   {'goalsHomeTeam': 1, 'goalsAwayTeam': 2, 'half...  FINISHED
# 16            {'goalsHomeTeam': 2, 'goalsAwayTeam': 0}  FINISHED
# 17            {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}  FINISHED
# 18            {'goalsHomeTeam': 1, 'goalsAwayTeam': 2}  FINISHED
# 23            {'goalsHomeTeam': 3, 'goalsAwayTeam': 4}  FINISHED
# 25            {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}  FINISHED
# 27            {'goalsHomeTeam': 1, 'goalsAwayTeam': 1}  FINISHED
# 29            {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}  FINISHED
# 30            {'goalsHomeTeam': 4, 'goalsAwayTeam': 1}  FINISHED
# 31            {'goalsHomeTeam': 3, 'goalsAwayTeam': 1}  FINISHED
# 32            {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}  FINISHED
# 34            {'goalsHomeTeam': 1, 'goalsAwayTeam': 1}  FINISHED
# 39            {'goalsHomeTeam': 3, 'goalsAwayTeam': 1}  FINISHED
# 40   {'goalsHomeTeam': 3, 'goalsAwayTeam': 1, 'half...  FINISHED
# 41   {'goalsHomeTeam': 3, 'goalsAwayTeam': 1, 'half...  FINISHED
# 43   {'goalsHomeTeam': 1, 'goalsAwayTeam': 1, 'half...  FINISHED
# 46   {'goalsHomeTeam': 4, 'goalsAwayTeam': 1, 'half...  FINISHED
# 47   {'goalsHomeTeam': 2, 'goalsAwayTeam': 0, 'half...  FINISHED
# 50   {'goalsHomeTeam': 2, 'goalsAwayTeam': 0, 'half...  FINISHED
# 52   {'goalsHomeTeam': 0, 'goalsAwayTeam': 1, 'half...  FINISHED
# 54   {'goalsHomeTeam': 0, 'goalsAwayTeam': 3, 'half...  FINISHED
# 55   {'goalsHomeTeam': 0, 'goalsAwayTeam': 0, 'half...  FINISHED
# 57   {'goalsHomeTeam': 1, 'goalsAwayTeam': 3, 'half...  FINISHED
# 61   {'goalsHomeTeam': 2, 'goalsAwayTeam': 1, 'half...  FINISHED
# ..                                                 ...       ...
# 248  {'goalsHomeTeam': 2, 'goalsAwayTeam': 1, 'half...  FINISHED
# 250  {'goalsHomeTeam': 4, 'goalsAwayTeam': 1, 'half...  FINISHED
# 251  {'goalsHomeTeam': 1, 'goalsAwayTeam': 2, 'half...  FINISHED
# 252  {'goalsHomeTeam': 1, 'goalsAwayTeam': 3, 'half...  FINISHED
# 253  {'goalsHomeTeam': 3, 'goalsAwayTeam': 0, 'half...  FINISHED
# 255  {'goalsHomeTeam': 2, 'goalsAwayTeam': 0, 'half...  FINISHED
# 258  {'goalsHomeTeam': 8, 'goalsAwayTeam': 0, 'half...  FINISHED
# 260  {'goalsHomeTeam': 2, 'goalsAwayTeam': 2, 'half...  FINISHED
# 261  {'goalsHomeTeam': 2, 'goalsAwayTeam': 3, 'half...  FINISHED
# 262  {'goalsHomeTeam': 4, 'goalsAwayTeam': 2, 'half...  FINISHED
# 264  {'goalsHomeTeam': 4, 'goalsAwayTeam': 3, 'half...  FINISHED
# 269  {'goalsHomeTeam': 5, 'goalsAwayTeam': 0, 'half...  FINISHED
# 272  {'goalsHomeTeam': 1, 'goalsAwayTeam': 1, 'half...  FINISHED
# 273  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0, 'half...  FINISHED
# 274  {'goalsHomeTeam': 3, 'goalsAwayTeam': 0, 'half...  FINISHED
# 276  {'goalsHomeTeam': 5, 'goalsAwayTeam': 1, 'half...  FINISHED
# 277  {'goalsHomeTeam': 2, 'goalsAwayTeam': 0, 'half...  FINISHED
# 279  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0, 'half...  FINISHED
# 285  {'goalsHomeTeam': 0, 'goalsAwayTeam': 1, 'half...  FINISHED
# 286  {'goalsHomeTeam': 0, 'goalsAwayTeam': 2, 'half...  FINISHED
# 287  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0, 'half...  FINISHED
# 288  {'goalsHomeTeam': 1, 'goalsAwayTeam': 1, 'half...  FINISHED
# 289  {'goalsHomeTeam': 3, 'goalsAwayTeam': 0, 'half...  FINISHED
# 295  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0, 'half...  FINISHED
# 299  {'goalsHomeTeam': 3, 'goalsAwayTeam': 1, 'half...  FINISHED
# 300  {'goalsHomeTeam': 0, 'goalsAwayTeam': 2, 'half...  FINISHED
# 301  {'goalsHomeTeam': 4, 'goalsAwayTeam': 1, 'half...  FINISHED
# 302  {'goalsHomeTeam': 3, 'goalsAwayTeam': 5, 'half...  FINISHED
# 303  {'goalsHomeTeam': 4, 'goalsAwayTeam': 1, 'half...  FINISHED
# 305  {'goalsHomeTeam': 3, 'goalsAwayTeam': 0, 'half...  FINISHED
#
#          real_timestamp  weekday         ...           goalsHomeTeam  \
# 1   2016-08-06 16:30:00        5         ...                       3
# 2   2016-08-06 17:45:00        5         ...                       1
# 5   2016-08-07 10:30:00        6         ...                       0
# 7   2016-08-07 12:30:00        6         ...                       1
# 9   2016-08-12 18:00:00        4         ...                       2
# 10  2016-08-13 16:30:00        5         ...                       2
# 12  2016-08-13 17:45:00        5         ...                       1
# 16  2016-08-14 12:30:00        6         ...                       2
# 17  2016-08-14 14:45:00        6         ...                       1
# 18  2016-08-19 18:00:00        4         ...                       1
# 23  2016-08-21 10:30:00        6         ...                       3
# 25  2016-08-21 12:30:00        6         ...                       1
# 27  2016-08-26 18:00:00        4         ...                       1
# 29  2016-08-27 17:45:00        5         ...                       1
# 30  2016-08-27 17:45:00        5         ...                       4
# 31  2016-08-27 18:45:00        5         ...                       3
# 32  2016-08-28 10:30:00        6         ...                       0
# 34  2016-08-28 12:30:00        6         ...                       1
# 39  2016-09-10 18:45:00        5         ...                       3
# 40  2016-09-10 18:45:00        5         ...                       3
# 41  2016-09-11 10:30:00        6         ...                       3
# 43  2016-09-11 12:30:00        6         ...                       1
# 46  2016-09-17 16:30:00        5         ...                       4
# 47  2016-09-17 17:45:00        5         ...                       2
# 50  2016-09-18 10:30:00        6         ...                       2
# 52  2016-09-18 12:30:00        6         ...                       0
# 54  2016-09-24 16:30:00        5         ...                       0
# 55  2016-09-24 16:30:00        5         ...                       0
# 57  2016-09-24 18:45:00        5         ...                       1
# 61  2016-09-25 12:30:00        6         ...                       2
# ..                  ...      ...         ...                     ...
# 248 2017-04-02 10:30:00        6         ...                       2
# 250 2017-04-02 12:30:00        6         ...                       4
# 251 2017-04-02 14:45:00        6         ...                       1
# 252 2017-04-04 16:30:00        1         ...                       1
# 253 2017-04-04 18:45:00        1         ...                       3
# 255 2017-04-05 17:45:00        2         ...                       2
# 258 2017-04-05 18:45:00        2         ...                       8
# 260 2017-04-06 18:45:00        3         ...                       2
# 261 2017-04-07 18:00:00        4         ...                       2
# 262 2017-04-08 16:30:00        5         ...                       4
# 264 2017-04-08 17:45:00        5         ...                       4
# 269 2017-04-09 14:45:00        6         ...                       5
# 272 2017-04-15 17:45:00        5         ...                       1
# 273 2017-04-15 17:45:00        5         ...                       1
# 274 2017-04-15 18:45:00        5         ...                       3
# 276 2017-04-16 12:30:00        6         ...                       5
# 277 2017-04-16 12:30:00        6         ...                       2
# 279 2017-04-21 18:00:00        4         ...                       1
# 285 2017-04-23 12:30:00        6         ...                       0
# 286 2017-04-23 12:30:00        6         ...                       0
# 287 2017-04-23 14:45:00        6         ...                       1
# 288 2017-05-07 12:30:00        6         ...                       1
# 289 2017-05-07 12:30:00        6         ...                       3
# 295 2017-05-07 12:30:00        6         ...                       1
# 299 2017-05-14 12:30:00        6         ...                       3
# 300 2017-05-14 12:30:00        6         ...                       0
# 301 2017-05-14 12:30:00        6         ...                       4
# 302 2017-05-14 12:30:00        6         ...                       3
# 303 2017-05-14 12:30:00        6         ...                       4
# 305 2017-05-14 12:30:00        6         ...                       3
#
#                                      halfTime outcome  Capacity        City  \
# 1    {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}       1   15000.0    Den Haag
# 2    {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}       2   30205.0    Enschede
# 5    {'goalsHomeTeam': 0, 'goalsAwayTeam': 3}       2   22579.0   Groningen
# 7    {'goalsHomeTeam': 1, 'goalsAwayTeam': 1}       2   11000.0   Rotterdam
# 9    {'goalsHomeTeam': 1, 'goalsAwayTeam': 2}       3  261000.0  Heerenveen
# 10   {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}       1    4400.0   Rotterdam
# 12   {'goalsHomeTeam': 1, 'goalsAwayTeam': 1}       2   25000.0      Arnhem
# 16                                        NaN       1   51117.0   Rotterdam
# 17                                        NaN       1   36500.0   Eindhoven
# 18                                        NaN       2    4400.0   Rotterdam
# 23                                        NaN       2   22579.0   Groningen
# 25                                        NaN       1   11000.0   Rotterdam
# 27                                        NaN       3   25000.0      Arnhem
# 29                                        NaN       1  261000.0  Heerenveen
# 30                                        NaN       1   51117.0   Rotterdam
# 31                                        NaN       1   30205.0    Enschede
# 32                                        NaN       3   36500.0   Eindhoven
# 34                                        NaN       3   15000.0    Den Haag
# 39                                        NaN       1  261000.0  Heerenveen
# 40   {'goalsHomeTeam': 3, 'goalsAwayTeam': 0}       1    4400.0   Rotterdam
# 41   {'goalsHomeTeam': 2, 'goalsAwayTeam': 0}       1   51117.0   Rotterdam
# 43   {'goalsHomeTeam': 1, 'goalsAwayTeam': 1}       3   22579.0   Groningen
# 46   {'goalsHomeTeam': 2, 'goalsAwayTeam': 0}       1   30205.0    Enschede
# 47   {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}       1   25000.0      Arnhem
# 50   {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}       1   11000.0   Rotterdam
# 52   {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}       2   36500.0   Eindhoven
# 54   {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}       2   15000.0    Den Haag
# 55   {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}       3   22579.0   Groningen
# 57   {'goalsHomeTeam': 1, 'goalsAwayTeam': 2}       2    4400.0   Rotterdam
# 61   {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}       1   30205.0    Enschede
# ..                                        ...     ...       ...         ...
# 248  {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}       1   25000.0      Arnhem
# 250  {'goalsHomeTeam': 2, 'goalsAwayTeam': 0}       1   15000.0    Den Haag
# 251  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}       2   30205.0    Enschede
# 252  {'goalsHomeTeam': 1, 'goalsAwayTeam': 1}       2    4400.0   Rotterdam
# 253  {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}       1  261000.0  Heerenveen
# 255  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}       1   22579.0   Groningen
# 258  {'goalsHomeTeam': 5, 'goalsAwayTeam': 0}       1   51117.0   Rotterdam
# 260  {'goalsHomeTeam': 1, 'goalsAwayTeam': 1}       3   30205.0    Enschede
# 261  {'goalsHomeTeam': 1, 'goalsAwayTeam': 2}       2   11000.0   Rotterdam
# 262  {'goalsHomeTeam': 2, 'goalsAwayTeam': 1}       1   25000.0      Arnhem
# 264  {'goalsHomeTeam': 3, 'goalsAwayTeam': 0}       1   15000.0    Den Haag
# 269  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}       1   36500.0   Eindhoven
# 272  {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}       3   15000.0    Den Haag
# 273  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}       1    4400.0   Rotterdam
# 274  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}       1   30205.0    Enschede
# 276  {'goalsHomeTeam': 3, 'goalsAwayTeam': 0}       1   22579.0   Groningen
# 277  {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}       1   51117.0   Rotterdam
# 279  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}       1  261000.0  Heerenveen
# 285  {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}       2   11000.0   Rotterdam
# 286  {'goalsHomeTeam': 0, 'goalsAwayTeam': 2}       2   25000.0      Arnhem
# 287  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}       1   36500.0   Eindhoven
# 288  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}       3   22579.0   Groningen
# 289  {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}       1    4400.0   Rotterdam
# 295  {'goalsHomeTeam': 0, 'goalsAwayTeam': 0}       1   11000.0   Rotterdam
# 299  {'goalsHomeTeam': 2, 'goalsAwayTeam': 0}       1   51117.0   Rotterdam
# 300  {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}       2  261000.0  Heerenveen
# 301  {'goalsHomeTeam': 0, 'goalsAwayTeam': 1}       1   36500.0   Eindhoven
# 302  {'goalsHomeTeam': 1, 'goalsAwayTeam': 4}       2   30205.0    Enschede
# 303  {'goalsHomeTeam': 3, 'goalsAwayTeam': 1}       1   15000.0    Den Haag
# 305  {'goalsHomeTeam': 1, 'goalsAwayTeam': 0}       1   25000.0      Arnhem
#
#      Lattitude Longitude                        Name  PitchType  \
# 1    52.062934  4.380538             Kyocera-stadion  Synthetic
# 2    52.236535  6.835670            De Grolsch Veste    Natural
# 5    53.206787  6.589806                    Euroborg    Natural
# 7    51.919956  4.430850  Sparta-Stadion Het Kasteel  Synthetic
# 9    52.958743  5.933824         Abe Lenstra Stadion    Natural
# 10   51.917516  4.517714          Stadion Woudestein    Natural
# 12   51.964289  5.889449                   GelreDome    Natural
# 16   51.893904  4.520947          Stadion Feijenoord    Natural
# 17   51.441462  5.466528              Philipsstadion    Natural
# 18   51.917516  4.517714          Stadion Woudestein    Natural
# 23   53.206787  6.589806                    Euroborg    Natural
# 25   51.919956  4.430850  Sparta-Stadion Het Kasteel  Synthetic
# 27   51.964289  5.889449                   GelreDome    Natural
# 29   52.958743  5.933824         Abe Lenstra Stadion    Natural
# 30   51.893904  4.520947          Stadion Feijenoord    Natural
# 31   52.236535  6.835670            De Grolsch Veste    Natural
# 32   51.441462  5.466528              Philipsstadion    Natural
# 34   52.062934  4.380538             Kyocera-stadion  Synthetic
# 39   52.958743  5.933824         Abe Lenstra Stadion    Natural
# 40   51.917516  4.517714          Stadion Woudestein    Natural
# 41   51.893904  4.520947          Stadion Feijenoord    Natural
# 43   53.206787  6.589806                    Euroborg    Natural
# 46   52.236535  6.835670            De Grolsch Veste    Natural
# 47   51.964289  5.889449                   GelreDome    Natural
# 50   51.919956  4.430850  Sparta-Stadion Het Kasteel  Synthetic
# 52   51.441462  5.466528              Philipsstadion    Natural
# 54   52.062934  4.380538             Kyocera-stadion  Synthetic
# 55   53.206787  6.589806                    Euroborg    Natural
# 57   51.917516  4.517714          Stadion Woudestein    Natural
# 61   52.236535  6.835670            De Grolsch Veste    Natural
# ..         ...       ...                         ...        ...
# 248  51.964289  5.889449                   GelreDome    Natural
# 250  52.062934  4.380538             Kyocera-stadion  Synthetic
# 251  52.236535  6.835670            De Grolsch Veste    Natural
# 252  51.917516  4.517714          Stadion Woudestein    Natural
# 253  52.958743  5.933824         Abe Lenstra Stadion    Natural
# 255  53.206787  6.589806                    Euroborg    Natural
# 258  51.893904  4.520947          Stadion Feijenoord    Natural
# 260  52.236535  6.835670            De Grolsch Veste    Natural
# 261  51.919956  4.430850  Sparta-Stadion Het Kasteel  Synthetic
# 262  51.964289  5.889449                   GelreDome    Natural
# 264  52.062934  4.380538             Kyocera-stadion  Synthetic
# 269  51.441462  5.466528              Philipsstadion    Natural
# 272  52.062934  4.380538             Kyocera-stadion  Synthetic
# 273  51.917516  4.517714          Stadion Woudestein    Natural
# 274  52.236535  6.835670            De Grolsch Veste    Natural
# 276  53.206787  6.589806                    Euroborg    Natural
# 277  51.893904  4.520947          Stadion Feijenoord    Natural
# 279  52.958743  5.933824         Abe Lenstra Stadion    Natural
# 285  51.919956  4.430850  Sparta-Stadion Het Kasteel  Synthetic
# 286  51.964289  5.889449                   GelreDome    Natural
# 287  51.441462  5.466528              Philipsstadion    Natural
# 288  53.206787  6.589806                    Euroborg    Natural
# 289  51.917516  4.517714          Stadion Woudestein    Natural
# 295  51.919956  4.430850  Sparta-Stadion Het Kasteel  Synthetic
# 299  51.893904  4.520947          Stadion Feijenoord    Natural
# 300  52.958743  5.933824         Abe Lenstra Stadion    Natural
# 301  51.441462  5.466528              Philipsstadion    Natural
# 302  52.236535  6.835670            De Grolsch Veste    Natural
# 303  52.062934  4.380538             Kyocera-stadion  Synthetic
# 305  51.964289  5.889449                   GelreDome    Natural
#
#                     Team
# 1           ADO Den Haag
# 2     FC Twente Enschede
# 5           FC Groningen
# 7       Sparta Rotterdam
# 9          SC Heerenveen
# 10             Excelsior
# 12        Vitesse Arnhem
# 16   Feyenoord Rotterdam
# 17         PSV Eindhoven
# 18             Excelsior
# 23          FC Groningen
# 25      Sparta Rotterdam
# 27        Vitesse Arnhem
# 29         SC Heerenveen
# 30   Feyenoord Rotterdam
# 31    FC Twente Enschede
# 32         PSV Eindhoven
# 34          ADO Den Haag
# 39         SC Heerenveen
# 40             Excelsior
# 41   Feyenoord Rotterdam
# 43          FC Groningen
# 46    FC Twente Enschede
# 47        Vitesse Arnhem
# 50      Sparta Rotterdam
# 52         PSV Eindhoven
# 54          ADO Den Haag
# 55          FC Groningen
# 57             Excelsior
# 61    FC Twente Enschede
# ..                   ...
# 248       Vitesse Arnhem
# 250         ADO Den Haag
# 251   FC Twente Enschede
# 252            Excelsior
# 253        SC Heerenveen
# 255         FC Groningen
# 258  Feyenoord Rotterdam
# 260   FC Twente Enschede
# 261     Sparta Rotterdam
# 262       Vitesse Arnhem
# 264         ADO Den Haag
# 269        PSV Eindhoven
# 272         ADO Den Haag
# 273            Excelsior
# 274   FC Twente Enschede
# 276         FC Groningen
# 277  Feyenoord Rotterdam
# 279        SC Heerenveen
# 285     Sparta Rotterdam
# 286       Vitesse Arnhem
# 287        PSV Eindhoven
# 288         FC Groningen
# 289            Excelsior
# 295     Sparta Rotterdam
# 299  Feyenoord Rotterdam
# 300        SC Heerenveen
# 301        PSV Eindhoven
# 302   FC Twente Enschede
# 303         ADO Den Haag
# 305       Vitesse Arnhem
#
# [153 rows x 22 columns]

# %%
# map of The Netherlands
fixtures_map = folium.Map(location=[52.1, 5.1483], zoom_start=7)

#function to determine the color of the icon
def icon_color(x):
      result = 'green'
      if x['goalsAwayTeam']> x['goalsHomeTeam']:
        result='red'
      elif x['goalsAwayTeam']== x['goalsHomeTeam']:
        result='blue'
      elif not (isinstance( x['goalsAwayTeam'], int )):
        result='gray'
      return result 

# add a marker for every record in the filtered data, use a clustered view
marker_cluster = folium.MarkerCluster("Public toilet cluster").add_to(fixtures_map)
for each in fixtures[fixtures.Longitude.notnull() & fixtures.Lattitude.notnull()].iterrows():
   folium.Marker([each[1]['Lattitude'],each[1]['Longitude']]
                 , popup=each[1]['real_timestamp'].strftime('%d %B %Y') # see https://docs.python.org/3.0/library/datetime.html?highlight=strftime#strftime-behavior for format strings
                   +': '+each[1]['homeTeamName']+'-'+each[1]['awayTeamName']
                 +' ('+str(each[1]['goalsHomeTeam'])+'-'+str(each[1]['goalsAwayTeam'])+')'
                 ,icon=folium.Icon(color=icon_color(each[1]))
                ).add_to(marker_cluster)
    
   
fixtures_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
fixtures_map.save('fixtures-map.html')

# %% [markdown]
# <a id="league-standings"/>

# %% [markdown]
# #Get League Standings for Each Match Day
#
# Load a Single Match Day's League Standing

# %%
leageStandingURL ="http://api.football-data.org/v1/competitions/433/leagueTable?matchday=12";
l = json.loads(requests.get(leageStandingURL, headers=headers).text)

standing = pd.DataFrame(l["standing"])
standing['matchDay'] = 0
standing.head(5)
# Out:
#                                               _links  \
# 0  {'team': {'href': 'http://api.football-data.or...
# 1  {'team': {'href': 'http://api.football-data.or...
# 2  {'team': {'href': 'http://api.football-data.or...
# 3  {'team': {'href': 'http://api.football-data.or...
# 4  {'team': {'href': 'http://api.football-data.or...
#
#                                                 away  \
# 0  {'goals': 11, 'goalsAgainst': 2, 'wins': 5, 'd...
# 1  {'goals': 13, 'goalsAgainst': 4, 'wins': 4, 'd...
# 2  {'goals': 16, 'goalsAgainst': 3, 'wins': 5, 'd...
# 3  {'goals': 15, 'goalsAgainst': 9, 'wins': 3, 'd...
# 4  {'goals': 6, 'goalsAgainst': 5, 'wins': 3, 'dr...
#
#                                             crestURI  draws  goalDifference  \
# 0  http://upload.wikimedia.org/wikipedia/de/2/24/...      2              21
# 1  http://upload.wikimedia.org/wikipedia/de/7/79/...      3              15
# 2  http://upload.wikimedia.org/wikipedia/de/0/05/...      4              14
# 3  http://upload.wikimedia.org/wikipedia/de/e/e7/...      4              11
# 4  https://upload.wikimedia.org/wikipedia/en/e/e0...      5               5
#
#    goals  goalsAgainst                                               home  \
# 0     28             7  {'goals': 17, 'goalsAgainst': 5, 'wins': 4, 'd...
# 1     26            11  {'goals': 13, 'goalsAgainst': 7, 'wins': 4, 'd...
# 2     20             6  {'goals': 4, 'goalsAgainst': 3, 'wins': 2, 'dr...
# 3     25            14  {'goals': 10, 'goalsAgainst': 5, 'wins': 3, 'd...
# 4     18            13  {'goals': 12, 'goalsAgainst': 8, 'wins': 2, 'd...
#
#    losses  playedGames  points  position             teamName  wins  matchDay
# 0       1           12      29         1  Feyenoord Rotterdam     9         0
# 1       1           12      27         2       Ajax Amsterdam     8         0
# 2       1           12      25         3        PSV Eindhoven     7         0
# 3       2           12      22         4        SC Heerenveen     6         0
# 4       2           12      20         5           AZ Alkmaar     5         0

# %%
def download_leaguestanding(matchDay):
    leageStandingURL_template ="http://api.football-data.org/v1/competitions/433/leagueTable?matchday={matchday}";
    url = leageStandingURL_template.format(matchday=matchDay) 
    l = json.loads(requests.get(url, headers=headers).text)
    standing = pd.DataFrame(l["standing"])
    standing['matchDay'] = matchDay
    #calculate number of points for the current leader in the table
    pointsNumberOne = standing[standing['position']==1].iloc[0]['points']
    #add a column pointsGap with the delta in points for each club
    standing['pointsGap']=standing['points']-pointsNumberOne
    return standing

# %%
# try out the function to download standings for a single match day
test = download_leaguestanding(32)
test.head(6)
# Out:
#                                               _links  \
# 0  {'team': {'href': 'http://api.football-data.or...
# 1  {'team': {'href': 'http://api.football-data.or...
# 2  {'team': {'href': 'http://api.football-data.or...
# 3  {'team': {'href': 'http://api.football-data.or...
# 4  {'team': {'href': 'http://api.football-data.or...
# 5  {'team': {'href': 'http://api.football-data.or...
#
#                                                 away  \
# 0  {'goals': 30, 'goalsAgainst': 11, 'wins': 11, ...
# 1  {'goals': 28, 'goalsAgainst': 10, 'wins': 10, ...
# 2  {'goals': 32, 'goalsAgainst': 13, 'wins': 9, '...
# 3  {'goals': 23, 'goalsAgainst': 19, 'wins': 7, '...
# 4  {'goals': 24, 'goalsAgainst': 25, 'wins': 7, '...
# 5  {'goals': 20, 'goalsAgainst': 18, 'wins': 6, '...
#
#                                             crestURI  draws  goalDifference  \
# 0  http://upload.wikimedia.org/wikipedia/de/2/24/...      4              62
# 1  http://upload.wikimedia.org/wikipedia/de/7/79/...      6              50
# 2  http://upload.wikimedia.org/wikipedia/de/0/05/...      9              42
# 3  http://upload.wikimedia.org/wikipedia/de/4/48/...      8              14
# 4  https://upload.wikimedia.org/wikipedia/en/e/e0...     13               6
# 5  http://upload.wikimedia.org/wikipedia/de/4/41/...      6               9
#
#    goals  goalsAgainst                                               home  \
# 0     83            21  {'goals': 53, 'goalsAgainst': 10, 'wins': 14, ...
# 1     72            22  {'goals': 44, 'goalsAgainst': 12, 'wins': 13, ...
# 2     63            21  {'goals': 31, 'goalsAgainst': 8, 'wins': 12, '...
# 3     50            36  {'goals': 27, 'goalsAgainst': 17, 'wins': 9, '...
# 4     53            47  {'goals': 29, 'goalsAgainst': 22, 'wins': 5, '...
# 5     48            39  {'goals': 28, 'goalsAgainst': 21, 'wins': 8, '...
#
#    losses  playedGames  points  position             teamName  wins  matchDay  \
# 0       3           32      79         1  Feyenoord Rotterdam    25        32
# 1       3           32      75         2       Ajax Amsterdam    23        32
# 2       2           32      72         3        PSV Eindhoven    21        32
# 3       8           32      56         4           FC Utrecht    16        32
# 4       7           32      49         5           AZ Alkmaar    12        32
# 5      12           32      48         6       Vitesse Arnhem    14        32
#
#    pointsGap
# 0          0
# 1         -4
# 2         -7
# 3        -23
# 4        -30
# 5        -31

# %%
#test[test['position']==1].iloc[0]['points']
#eagueId = league.iloc[0]['id']
#test['pointsGap']=test['points']-test[test['position']==1].iloc[0]['points']
test[['position','points','pointsGap']]
# Out:
#     position  points  pointsGap
# 0          1      79          0
# 1          2      75         -4
# 2          3      72         -7
# 3          4      56        -23
# 4          5      49        -30
# 5          6      48        -31
# 6          7      45        -34
# 7          8      43        -36
# 8          9      40        -39
# 9         10      39        -40
# 10        11      36        -43
# 11        12      35        -44
# 12        13      34        -45
# 13        14      32        -47
# 14        15      30        -49
# 15        16      28        -51
# 16        17      28        -51
# 17        18      23        -56

# %% [markdown]
# ## Download all league standings
# Download the league standings for each match day. Concat the data per match day together into a single data frame.

# %%
# loop over all matchdays; for each match day, invoke the function to download the standings for that day
standings_by_matchday = [download_leaguestanding(i) for i in range(1, 34)]
# combine all results into a single data frame
all_standings = pd.concat(standings_by_matchday)
# show results from the combined data frame
all_standings.tail(20)

# %%
# add section for matchDay 0 - start of the competition
z = all_standings[all_standings['matchDay']==1].copy()
z['draws']=0
z['playedGames']=0
z['wins']=0
z['matchDay']=0
z['goals']=0
z['goalsAgainst']=0
z['goalDifference']=0
z['position']=1
z['points']=0
z['away']="{}"
z['home']="{}"


all_standings = pd.concat([z,all_standings])

# %%
#create function to determine the series of points collected by a team in a number of matches prior to a specific matchday
def streak(team, fromMatchDay, streak):
    points = all_standings[(all_standings['teamName']==team) & (all_standings['matchDay']==max(0,fromMatchDay-1))]['points'].iloc[0] - all_standings[(all_standings['teamName']==team) & (all_standings['matchDay']== max(0,(fromMatchDay-1-streak)))]['points'].iloc[0]
    return points

def teamStreak3(standing):      
      return streak(standing['teamName'],standing['matchDay'],3) 
    
streak(team,1,3)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-340-82503b414e8d> in <module>()
#       7       return streak(standing['teamName'],standing['matchDay'],3)
#       8
# ----> 9 streak(team,1,3)
#
# <ipython-input-340-82503b414e8d> in streak(team, fromMatchDay, streak)
#       1 #create function to determine the series of points collected by a team in a number of matches prior to a specific matchday
#       2 def streak(team, fromMatchDay, streak):
# ----> 3     points = all_standings[(all_standings['teamName']==team) & (all_standings['matchDay']==max(0,fromMatchDay-1))]['points'].iloc[0] - all_standings[(all_standings['teamName']==team) & (all_standings['matchDay']== max(0,(fromMatchDay-1-streak)))]['points'].iloc[0]
#       4     return points
#       5
#
# /home/python/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1310             return self._getitem_tuple(key)
#    1311         else:
# -> 1312             return self._getitem_axis(key, axis=0)
#    1313
#    1314     def _getitem_axis(self, key, axis=0):
#
# /home/python/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1626
#    1627                 # validate the location
# -> 1628                 self._is_valid_integer(key, axis)
#    1629
#    1630             return self._get_loc(key, axis=axis)
#
# /home/python/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _is_valid_integer(self, key, axis)
#    1540         l = len(ax)
#    1541         if key >= l or key < -l:
# -> 1542             raise IndexError("single positional indexer is out-of-bounds")
#    1543         return True
#    1544
#
# IndexError: single positional indexer is out-of-bounds

# %%
# add column streak3 to the all_standings dataframe to hold the number of points gained by a team in the three play days prior to the current match day 
all_standings['streak3'] = all_standings.apply(teamStreak3, axis=1)

# %% [markdown]
# #Plots based on leaguestandings
#
# For example a line chart for the traditional top 3 with their week by week points total

# %%
import matplotlib.pyplot as plt

#used docs on line chart : https://matplotlib.org/users/pyplot_tutorial.html
# also: http://mple.m-artwork.eu/tutorial

plt.figure(figsize=(20,10)) 
l_h =[]
for team in ['Feyenoord Rotterdam', 'Ajax Amsterdam', 'PSV Eindhoven','ADO Den Haag']:
    h, = plt.plot(all_standings[all_standings['teamName']==team]['matchDay']
                 ,all_standings[all_standings['teamName']==team]['points']
                ,label=team)
    l_h.append(h)
plt.legend(handles=l_h)
plt.ylabel('Total points')
plt.xlabel('Matchday')
plt.title('Points throughout season for top contenders and ADO Den Haag')

# add annotation for PSV-AJAX
plt.annotate('PSV-AJAX', xy=(30.9, 75), xytext=(28, 76.5),
            arrowprops=dict(facecolor='black', shrink=0.05),
            )
plt.show()

# %%
#pointsgap
plt.figure(figsize=(20,10)) 
l_h =[]
for team in ['Feyenoord Rotterdam', 'Ajax Amsterdam', 'PSV Eindhoven','ADO Den Haag']:
    h, = plt.plot(all_standings[all_standings['teamName']==team]['matchDay']
                 ,all_standings[all_standings['teamName']==team]['pointsGap']
                ,label=team)
    l_h.append(h)
plt.legend(handles=l_h)
plt.ylabel('Points gap with number one')
plt.xlabel('Matchday')
plt.title('Points gap throughout season for top contenders and ADO Den Haag')
plt.show()

# %% [markdown]
# Combine fixtures and standings - add points difference between teams in fixture

# %%
def points_for_team(team, matchday):
  return all_standings[(all_standings['teamName']==team) & (all_standings['matchDay']==matchday) ].iloc[0]['points']

def pointsgap(fixture):
  if (fixture['matchday'] > 34):
      return 0
  else:     
    #note: the pointsgap prior to fixture is calculated using the points from (after) the previous matchday    
    points_home= points_for_team(fixture['homeTeamName'],fixture['matchday']-1);
    points_away= points_for_team(fixture['awayTeamName'],fixture['matchday']-1);
    return points_home - points_away

# %%
# add column priorPointsGap to the fixtures dataframe to hold te gap in points between the two teams, as existed just prior to the fixture
fixtures['priorPointsGap'] = fixtures.apply(pointsgap, axis=1)
#fixtures.head(30)

# %%
def streak3_for_team(team, matchday):
  return all_standings[(all_standings['teamName']==team) & (all_standings['matchDay']==matchday) ].iloc[0]['streak3']


#check http://stackoverflow.com/questions/30026815/add-multiple-columns-to-pandas-dataframe-from-function to create two columns in one go
def streak3(fixture):  
  homestreak = 0;
  if (fixture['matchday']) > 1 :
        homestreak = streak3_for_team(fixture['homeTeamName'],min(fixture['matchday'],34))
  awaystreak = 0;
  if (fixture['matchday']) > 1 :
        awaystreak = streak3_for_team(fixture['awayTeamName'],min(fixture['matchday'],34)
  return pd.Series([homestreak, awaystreak, homestreak/min(fixture['matchday'],3),awaystreak/min(fixture['matchday'],3)])

streak3_for_team('Ajax Amsterdam',34)

# %%
# add column homeStreak3 to the fixtures dataframe to hold the point streak over 3 prior games
#fixtures['homeStreak3'] = fixtures.apply(homestreak3, axis=1)

fixtures[['homeStreak3', 'awayStreak3', 'homeStreak3Avg','awayStreak3Avg']] = fixtures.apply(streak3, axis=1)

# %%
fixtures.tail(50)

# %%
#create area chart with from fixtures per week the count per outcome (1,2 or 3)

counts= fixtures.groupby(['matchday', 'outcome'])[['status']].count().unstack('outcome')
counts['status']
# Out:
# outcome     1    2    3
# matchday
# 1         1.0  5.0  3.0
# 2         4.0  2.0  3.0
# 3         2.0  7.0  NaN
# 4         4.0  1.0  4.0
# 5         6.0  1.0  2.0
# 6         3.0  5.0  1.0
# 7         4.0  2.0  3.0
# 8         4.0  2.0  3.0
# 9         1.0  4.0  4.0
# 10        3.0  3.0  3.0
# 11        3.0  2.0  4.0
# 12        4.0  1.0  4.0
# 13        5.0  NaN  4.0
# 14        3.0  3.0  3.0
# 15        4.0  2.0  3.0
# 16        6.0  2.0  1.0
# 17        4.0  1.0  4.0
# 18        3.0  6.0  NaN
# 19        4.0  2.0  3.0
# 20        5.0  3.0  1.0
# 21        1.0  7.0  1.0
# 22        5.0  2.0  2.0
# 23        5.0  2.0  2.0
# 24        3.0  4.0  2.0
# 25        5.0  NaN  4.0
# 26        8.0  1.0  NaN
# 27        3.0  4.0  2.0
# 28        5.0  2.0  2.0
# 29        5.0  3.0  1.0
# 30        4.0  3.0  2.0
# 31        7.0  1.0  1.0
# 32        4.0  5.0  NaN
# 33        8.0  NaN  1.0
# 34        4.0  5.0  NaN

# %%
counts.plot(kind='bar',stacked=True,title="Distribution Home Win/Away Win/Draw per Matchday",figsize=(20, 10))
plt.ylabel('Result')
plt.xlabel('Matchday')

plt.show()

# %%
counts.plot(kind='area',stacked=True,title="Distribution Home Win/Away Win/Draw per Matchday",figsize=(20, 10))
plt.ylabel('Result')
plt.xlabel('Matchday')


daysofweek = {1:('Sunday','r'), 
              2:('Monday','g'), 
              3:('Tuesday','b'), 
              4:('Wednesday','yellow'), 
              5:('Thursday','k'), 
              6:('Friday', 'magenta'), 
              7:('Saturday', 'orange')}
plt.show()

# %%
counts= fixtures.groupby(['matchday', 'outcome'])[['status']].count().reset_index()
counts.rename(columns={'status': 'outcome_count'}, inplace=True)
counts
